# %%
import numpy as np
import pandas as pd

# %%
#read CSV
t1 = pd.read_csv("dataset.csv")
t1
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10           6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %%
#l1 = t1['Medal']
#l1
# Out:
# 0            NaN
# 1            NaN
# 2            NaN
# 3           Gold
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
#            ...
# 271086       NaN
# 271087       NaN
# 271088       NaN
# 271089       NaN
# 271090       NaN
# 271091       NaN
# 271092       NaN
# 271093       NaN
# 271094       NaN
# 271095       NaN
# 271096       NaN
# 271097       NaN
# 271098       NaN
# 271099       NaN
# 271100       NaN
# 271101       NaN
# 271102    Bronze
# 271103    Silver
# 271104       NaN
# 271105       NaN
# 271106       NaN
# ...

# %%
#t1.loc[-2:,["Medal"]]=np.nan

# %%
#None values count in CSV
null_columns=t1.columns[t1.isnull().any()]
t1[null_columns].isnull().sum()
# Out:
# Age         9474
# Height     60171
# Weight     62875
# Medal     231333
# dtype: int64

# %%
#Filtering data only from 1900-2016
t2 = t1[t1['Year'].between(1900,2016, inclusive = True)]
t2
# Out:
#             ID                                Name Sex   Age  Height  Weight  \
# 0            1                           A Dijiang   M  24.0   180.0    80.0
# 1            2                            A Lamusi   M  23.0   170.0    60.0
# 2            3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 5            5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# 6            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 7            5            Christine Jacoba Aaftink   F  25.0   185.0    82.0
# 8            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 9            5            Christine Jacoba Aaftink   F  27.0   185.0    82.0
# 10           6                     Per Knut Aaland   M  31.0   188.0    75.0
# ...

# %%
#null valuescount b/w 1900-2016
null_columns2 =t2.columns[t2.isnull().any()]
t2[null_columns].isnull().sum()
# Out:
# Age         9311
# Height     59837
# Weight     62544
# Medal     231096
# dtype: int64

# %%
#Drop all NaN values in Medal
t2 = t2.dropna(subset=['Medal'])
t2
# Out:
#             ID                                       Name Sex   Age  Height  \
# 3            4                       Edgar Lindenau Aabye   M  34.0     NaN
# 37          15                       Arvo Ossian Aaltonen   M  30.0     NaN
# 38          15                       Arvo Ossian Aaltonen   M  30.0     NaN
# 40          16                   Juhamatti Tapio Aaltonen   M  28.0   184.0
# 41          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 42          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 44          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 48          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 50          17                    Paavo Johannes Aaltonen   M  32.0   175.0
# 60          20                         Kjetil Andr Aamodt   M  20.0   176.0
# 61          20                         Kjetil Andr Aamodt   M  20.0   176.0
# ...

# %%
t2.count()
# Out:
# ID        39640
# Name      39640
# Sex       39640
# Age       38950
# Height    31050
# Weight    30434
# Team      39640
# NOC       39640
# Games     39640
# Year      39640
# Season    39640
# City      39640
# Sport     39640
# Event     39640
# Medal     39640
# dtype: int64

# %%
t2.to_csv("rd1.csv", index = False)

# %%
t2
# Out:
#             ID                                       Name Sex   Age  Height  \
# 3            4                       Edgar Lindenau Aabye   M  34.0     NaN
# 37          15                       Arvo Ossian Aaltonen   M  30.0     NaN
# 38          15                       Arvo Ossian Aaltonen   M  30.0     NaN
# 40          16                   Juhamatti Tapio Aaltonen   M  28.0   184.0
# 41          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 42          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 44          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 48          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 50          17                    Paavo Johannes Aaltonen   M  32.0   175.0
# 60          20                         Kjetil Andr Aamodt   M  20.0   176.0
# 61          20                         Kjetil Andr Aamodt   M  20.0   176.0
# ...

# %%
t2.describe
# Out:
# <bound method NDFrame.describe of             ID                                       Name Sex   Age  Height  \
# 3            4                       Edgar Lindenau Aabye   M  34.0     NaN
# 37          15                       Arvo Ossian Aaltonen   M  30.0     NaN
# 38          15                       Arvo Ossian Aaltonen   M  30.0     NaN
# 40          16                   Juhamatti Tapio Aaltonen   M  28.0   184.0
# 41          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 42          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 44          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 48          17                    Paavo Johannes Aaltonen   M  28.0   175.0
# 50          17                    Paavo Johannes Aaltonen   M  32.0   175.0
# 60          20                         Kjetil Andr Aamodt   M  20.0   176.0
# 61          20                         Kjetil Andr Aamodt   M  20.0   176.0
# ...
