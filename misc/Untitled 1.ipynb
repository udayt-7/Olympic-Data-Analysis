# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys


df = pd.read_csv('rd1.csv')	
#print(df)

ds = pd.read_csv('summer.csv')
#print(ds)

dw = pd.read_csv('winter.csv')
#print(dw)

# %%
x = df.groupby('Year')['ID'].count()
#x=t1.groupby("Year")["ID"].count()
population=pd.DataFrame({'Year':x.index,'player_count':x.values})
objects = population['Year']
y_pos = np.arange(len(objects))
performance=population['player_count']
plt.figure(figsize=(15, 4))
plt.bar(y_pos, performance, align = 'center',alpha= 1)
plt.xticks(y_pos, objects,rotation=90)
plt.ylabel('Participants')
plt.xlabel('year')
plt.title('Partcipants by year')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Fixing random state for reproducibility
np.random.seed(19680801)


N = 50
x = np.random.rand(N)
y = np.random.rand(N)
colors = np.random.rand(N)
area = np.random.randint(100,1000,50) #(30 * np.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)

plt.show()

# %%
len(area)
# Out:
# 50

# %%
np.random.randint(10,100,50)
# Out:
# array([60, 28, 74, 26, 14, 60, 63, 38, 31, 95, 16, 67, 94, 35, 45, 55, 76,
#        54, 85, 45, 55, 97, 70, 66, 33, 67, 22, 97, 51, 63, 56, 76, 12, 59,
#        68, 81, 15, 20, 51, 38, 75, 49, 45, 17, 91, 86, 43, 10, 90, 30])
