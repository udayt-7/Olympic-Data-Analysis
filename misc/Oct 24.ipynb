# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sys

df = pd.read_csv('rd1.csv')	
# print(df)

a2 = df[df['Season']=='Summer']
a2.to_csv("summer.csv",index = False)
ds = pd.read_csv('summer.csv')
#print(ds)

a3 = df[df['Season']=='Winter']
a3.to_csv('winter.csv', index = False)
dw = pd.read_csv('winter.csv')
#print(dw)

# %%
yearsplit = ds[ds['Year'].between(2000,2016, inclusive = True)].sort_values(['Year','Season'],ascending = False)

y1 = ds[ds.Year==2000]
y2 = ds[ds.Year==2004]
y3 = ds[ds.Year==2008]
y4 = ds[ds.Year==2012]
y5 = ds[ds.Year==2016]

# %%
aage = yearsplit[['Year','Sport','Age']]

z = yearsplit.groupby(['Year','Sport']).agg({'Age':'mean'})

#z = y1.groupby(['Sport']).agg({'Age':'mean'})

# %%
ind = dw[dw.NOC== 'IND']
ind
# Out:
#           ID            Name Sex   Age  Height  Weight   Team  NOC  \
# 4535  109611  Antarge Sherpa   M  26.0   175.0    71.0  India  IND
# 4536  109613   Lhakpa Sherpa   M  26.0   175.0    71.0  India  IND
# 4537  109614    Narbu Sherpa   M  26.0   175.0    71.0  India  IND
# 4538  109615   Pasang Sherpa   M  26.0   175.0    71.0  India  IND
# 4539  109616   Pembra Sherpa   M  26.0   175.0    71.0  India  IND
# 4540  109617    Sange Sherpa   M  26.0   175.0    71.0  India  IND
# 4541  109618    Temba Sherpa   M  26.0   175.0    71.0  India  IND
#
#             Games  Year  Season      City     Sport                    Event  \
# 4535  1924 Winter  1924  Winter  Chamonix  Alpinism  Alpinism Mixed Alpinism
# 4536  1924 Winter  1924  Winter  Chamonix  Alpinism  Alpinism Mixed Alpinism
# 4537  1924 Winter  1924  Winter  Chamonix  Alpinism  Alpinism Mixed Alpinism
# 4538  1924 Winter  1924  Winter  Chamonix  Alpinism  Alpinism Mixed Alpinism
# 4539  1924 Winter  1924  Winter  Chamonix  Alpinism  Alpinism Mixed Alpinism
# 4540  1924 Winter  1924  Winter  Chamonix  Alpinism  Alpinism Mixed Alpinism
# 4541  1924 Winter  1924  Winter  Chamonix  Alpinism  Alpinism Mixed Alpinism
#
#      Medal
# 4535  Gold
# 4536  Gold
# 4537  Gold
# 4538  Gold
# 4539  Gold
# 4540  Gold
# 4541  Gold
